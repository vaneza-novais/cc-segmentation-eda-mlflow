# %%
from pathlib import Path

from loguru import logger
from tqdm import tqdm
import typer

from src.config import REPORTS_DIR
import pandas as pd

input_path_cluster: Path = REPORTS_DIR / 'perfil_clusters.csv'

df = pd.read_csv(input_path_cluster)

df
# Out:
#    cluster  log__ONEOFF_PURCHASES  log__CASH_ADVANCE_FREQUENCY  \
# 0        0               0.835176                    -0.315753
# 1        1              -0.980722                     0.814650
# 2        2               1.119455                    -0.352589
# 3        3              -0.979087                    -0.526150
# 4        4               0.819301                     0.225347
# 5        5              -0.238035                    -0.370557
#
#    quantil__BALANCE_FREQUENCY  quantil__PURCHASES_FREQUENCY  \
# 0                   -1.421742                     -0.029651
# 1                    0.190022                     -1.391416
# 2                    0.597737                      1.220533
# 3                   -0.125640                      0.592344
# 4                    0.653922                      0.036223
# 5                   -1.508347                     -0.206892
#
#    quantil__ONEOFF_PURCHASES_FREQUENCY  \
# 0                             0.744911
# 1                            -0.979238
# 2                             1.146516
# 3                            -0.975332
# 4                             0.805829
# 5                            -0.204213
#
#    quantil__PURCHASES_INSTALLMENTS_FREQUENCY  quantil__PRC_FULL_PAYMENT  \
# 0                                  -0.411693                   0.360628
# 1                                  -0.953409                  -0.317427
# 2                                   1.056909                   0.483032
# 3                                   0.884959                   0.478229
# 4                                  -0.392078                  -0.483844
# 5                                  -0.253605                  -0.686468
#
#    remainder__null_minimum_payments  qtde_por_cluster
# 0                         -0.189814               215
# 1                         -0.189814               392
# 2                         -0.189814               303
# 3                         -0.189814               409
# 4                         -0.189814               407
# 5                          5.268303                64
